# %%
# !git clone https://github.com/charan-poddaturi/pytorchtutorial.git
# Out:
# Cloning into 'pytorchtutorial'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 93 (delta 44), reused 70 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (93/93), 3.98 MiB | 21.36 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
