# %%
import torch
x = torch.tensor(3.0,requires_grad=True)
y = x**2
x
y
y.backward()
x.grad
# Out:
# tensor(6.)

# %%
x = torch.tensor(3.0,requires_grad=True)
y = x**2   
z = torch.sin(y)
z.backward()
x.grad
# Out:
# tensor(-5.4668)

# %%
heyy
