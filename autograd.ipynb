# %%
import torch
x = torch.tensor(3.0,requires_grad=True)
y = x**2
x
y
y.backward()
x.grad
# Out:
# tensor(6.)

# %%
x = torch.tensor(3.0,requires_grad=True)
y = x**2   
z = torch.sin(y)
z.backward()
x.grad
# Out:
# tensor(-5.4668)

# %%
x = torch.tensor(6.8)
y = torch.tensor(0.0)

w = torch.tensor(1.0)
b = torch.tensor(0.0)

# %%
def binary_crossentropy_loss(prediction,target):
    epsilon = 1e-8
    prediction = torch.clamp(prediction,epsilon,1-epsilon)
    return - (target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
z = w * x + b
y_pred = torch.sigmoid(z)
loss = binary_crossentropy_loss(y_pred,y)

# %%
loss
# Out:
# tensor(6.8011)

# %%
dloss_dy_pred = (y_pred - y) / (y_pred * (1 - y_pred))
dy_pred_dz = y_pred * (1 - y_pred)
dz_dw = x
dz_db = 1

dloss_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dloss_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual gradients of loss wrt weight(dw) and wrt bias(db): {dloss_dw}, {dloss_db}")
# Out:
# Manual gradients of loss wrt weight(dw) and wrt bias(db): 6.792435169219971, 0.9988874793052673

# %%
x = torch.tensor(6.8)
y = torch.tensor(0.0)

# %%
w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# %%
z = w*x + b
y_pred = torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9989, grad_fn=<SigmoidBackward0>)

# %%
loss = binary_crossentropy_loss(y_pred,y)
loss
# Out:
# tensor(6.8011, grad_fn=<NegBackward0>)

# %% [markdown]
# look at the computational graph available in the repo

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.7924)
# tensor(0.9989)

# %%
x = torch.tensor([1.0,2.0,3.0], requires_grad=True)
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = (x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
#clearing gradients
x =torch.tensor(2.0, requires_grad=True)

# %% [markdown]
# when i run the cell below it keeps changing the gradients instead of clearing them.

# %%
y = x **2
y.backward()
x.grad
# Out:
# tensor(4.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %% [markdown]
# when we no longer need to track gradients we use this
# option 1 - requires_grad_(False)
# option 2 - detach()
# option 3 - torch.no_grad()

# %%
x.requires_grad_(False)
# Out:
# tensor(2.)

# %%
x
# Out:
# tensor(2.)

# %%
y = x**2
y
# Out:
# tensor(4.)

# %% [markdown]
# now we cannot call backward function

# %%
y.backward()

# %%
x = torch.tensor(3.0,requires_grad=True)
z = x.detach()
z
# Out:
# tensor(3.)

# %%
y = x**2

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y1 = z**2
y1
# Out:
# tensor(9.)

# %% [markdown]
# now we cant use backward function

# %%
y1.backward()

# %%
x = torch.tensor(3.0,requires_grad=True)
x
# Out:
# tensor(3., requires_grad=True)

# %%
with torch.no_grad():
    y = x**2

# %%
y
# Out:
# tensor(9.)

# %% [markdown]
# now we cant use backward function

# %%
y.backward()
