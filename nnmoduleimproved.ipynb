# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in c:\ml_env\venv\lib\site-packages (2.10.0)
# Requirement already satisfied: filelock in c:\ml_env\venv\lib\site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\ml_env\venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\ml_env\venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\ml_env\venv\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\ml_env\venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\ml_env\venv\lib\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: setuptools in c:\ml_env\venv\lib\site-packages (from torch) (82.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\ml_env\venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\ml_env\venv\lib\site-packages (from jinja2->torch) (3.0.3)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# create model class using normal forward function and not using sequential container 
# import torch 
# import torch.nn as nn
# class Model(nn.Module):
#     def __init__(self,num_features):
#         super().__init__()
#         self.Linear1 = nn.Linear(num_features,3)
#         self.ReLu = nn.ReLU() 
#         self.Linear2 = nn.Linear(3,1)
#         self.sigmoid = nn.Sigmoid()

#     def forward(self,features):
#         out = self.Linear1(features)
#         out = self.ReLu(out)
#         out = self.Linear2(out)
#         out = self.sigmoid(out)

#         return out

# %%
# using sequential container to create model class
import torch
import torch.nn as nn
class Model(nn.Module):
    def __init__(self,num_features):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(num_features,3),
            nn.ReLU(),
            nn.Linear(3,1),
            nn.Sigmoid()
        )   
    
    def forward(self,features):
        return self.network(features)

# %%
features = torch.rand(10,5)
model = Model(features.shape[1])
model(features)
# Out:
# tensor([[0.5550],
#         [0.5570],
#         [0.5530],
#         [0.5768],
#         [0.5614],
#         [0.5788],
#         [0.5560],
#         [0.5591],
#         [0.5455],
#         [0.5617]], grad_fn=<SigmoidBackward0>)

# %%
model.Linear.weight
# Out:
# Parameter containing:
# tensor([[-0.0883,  0.3361,  0.1870,  0.4157, -0.0029],
#         [ 0.2669,  0.1791,  0.3728,  0.3712,  0.4106],
#         [-0.1943,  0.4189, -0.3077, -0.0249,  0.3484]], requires_grad=True)

# %%
model.Linear1.bias
# Out:
# Parameter containing:
# tensor([0.4441, 0.0928, 0.3626], requires_grad=True)

# %%
model.Linear2.weight
# Out:
# Parameter containing:
# tensor([[ 0.4544,  0.2686, -0.5649]], requires_grad=True)

# %%
model.Linear2.bias
# Out:
# Parameter containing:
# tensor([-0.5753], requires_grad=True)

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in c:\ml_env\venv\lib\site-packages (1.8.0)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from torchinfo import summary
summary(model,input_size=(10,5))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model                                    [10, 1]                   --
# ├─Linear: 1-1                            [10, 3]                   18
# ├─ReLU: 1-2                              [10, 3]                   --
# ├─Linear: 1-3                            [10, 1]                   4
# ├─Sigmoid: 1-4                           [10, 1]                   --
# ==========================================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================
